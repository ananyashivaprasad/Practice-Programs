# %%
num1=float(input("Enter a number:"))
num2=float(input("Enter a number:"))
print("\nChoose an operation, 1. Additon, 2. Subtraction, 3. Multiplication, 4.Division")
choice=int(input("Enter your choice from 1 to 4:"))
if choice==1:
 print("The addtion of the numbers provided are:" , num1+num2)
elif choice==2:
 print("The subtraction of the numbers provided are", num1-num2)
elif choice==3:
 print("The multiplication of the numbers provided are", num1*num2)
elif choice==4:
    if (num2!=0):
     print("The division of the numbers provided", num1/num2)
    else :
        print("cannot divide")
else:
 print("Incorrect Values provided")
# Out:
# Enter a number: 4
# Enter a number: 0
# Choose an operation, 1. Additon, 2. Subtraction, 3. Multiplication, 4.Division
# Enter your choice from 1 to 4: 4
# cannot divide
