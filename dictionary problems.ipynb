# %%
#sort the elements of the dictionary using sorted() fucntion
mydict={
"name":"ABC",
"panel":"B",
"rollno.":34,
"marks":[65,87,676,94]
}
sorted_dict=sorted(mydict)
print("Sorted keys:", sorted_dict)
# Out:
# Sorted keys: ['marks', 'name', 'panel', 'rollno.']

# %%
#dictionary of 5 students with their marks

marks={"Anishka":"101", "Evara":"190", "Avantika":"160", "Bhavitha":"170", "Kieran":"180"}
print("Student with highest marks:", [1])
highest_student=max(marks, key=marks.get)
print("Student with highest marks:", highest_student)
print("Highest marks", marks[highest_student])
# Out:
# Student with highest marks: [1]
# Student with highest marks: Evara
# Highest marks 190

# %%
#program to count the frequency of numbers in the dictionary
numbers={10,20,30,10,20,30,30,40,50,10,20,20}
frequency={}
for num in numbers:
 if num in frequency:
     frequency [num]=frequency[num]+1
else:
    frequency[num]=1
print("frequency of numbers", frequency)
# Out:
# frequency of numbers {30: 1}

# %%
#program to sort dictionary by values
my_dict={"Amit":"1", "Anushka":"2", "Tanishqa":"3"}
sorted_dict=dict(sorted(my_dict.items(), key=lambda items: items[1]))
print("Dict sorted by values:", sorted_dict)
# Out:
# Dict sorted by values: {'Amit': '1', 'Anushka': '2', 'Tanishqa': '3'}

# %%
my_dict={"Amit":"1", "Anushka":"2", "Tanishqa":"3"}
sorted_dict=dict(sorted(my_dict.items(), key=lambda items: items[1], reverse=True))
print("Dict sorted by values:", sorted_dict)
# Out:
# Dict sorted by values: {'Tanishqa': '3', 'Anushka': '2', 'Amit': '1'}
